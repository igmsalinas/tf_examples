# %%
import numpy as np

def reweight_distribution(original_distribution, temperature=0.5):
    distribution = np.log(original_distribution) / temperature
    distribution = np.exp(distribution)
    return distribution / np.sum(distribution)

# %%
# !wget https://ai.stanford.edu/~amaas/data/sentiment/aclImdb_v1.tar.gz
# !tar -xf aclImdb_v1.tar.gz

# %%
import tensorflow as tf
from tensorflow import keras

dataset = keras.utils.text_dataset_from_directory(directory='./aclImdb', label_mode=None, batch_size=256)
dataset = dataset.map(lambda x: tf.strings.regex_replace(x, "<br />", " "))

# %%
from tensorflow.keras.layers import TextVectorization

sequence_length = 100
vocab_size = 15000

text_vectorization = TextVectorization(
    max_tokens=vocab_size,
    output_mode='int',
    output_sequence_length=sequence_length
)

text_vectorization.adapt(dataset)

# %%
def prepare_lm_dataset(text_batch):
    vectorized_sequences = text_vectorization(text_batch)
    x = vectorized_sequences[:, :-1]
    y = vectorized_sequences[:, 1:]
    return x, y

lm_dataset = dataset.map(prepare_lm_dataset)

# %%
from tensorflow.keras import layers

# %%
class TransformerDecoder(layers.Layer):
    def __init__(self, embed_dim, dense_dim, num_heads, **kwargs):
        super().__init__(**kwargs)
        self.embed_dim = embed_dim
        self.dense_dim = dense_dim
        self.num_heads = num_heads
        self.attention1 = layers.MultiHeadAttention(num_heads=num_heads, key_dim=embed_dim)
        self.attention2 = layers.MultiHeadAttention(num_heads=num_heads, key_dim=embed_dim)
        self.dense_projection = keras.Sequential([layers.Dense(dense_dim, activation="relu"), layers.Dense(embed_dim)])
        self.layer_norm1 = layers.LayerNormalization()
        self.layer_norm2 = layers.LayerNormalization()
        self.layer_norm3 = layers.LayerNormalization()
        self.supports_masking = True
        
    def get_config(self):
        config = super().get_config()
        config.update({
            'embed_dim': self.embed_dim,
            'dense_dim': self.dense_dim,
            'num_heads': self.num_heads
        })
        return config
    
    def get_causal_attention_mask(self, inputs):
        input_shape = tf.shape(inputs)
        batch_size, seq_length = input_shape[0], input_shape[1]
        i = tf.range(seq_length)[:, tf.newaxis]
        j = tf.range(seq_length)
        mask = tf.cast(i >= j, dtype="int32")
        mask = tf.reshape(mask, (1, input_shape[1], input_shape[1]))
        mult = tf.concat([tf.expand_dims(batch_size, -1), tf.constant([1, 1], dtype="int32")], axis=0)
        return tf.tile(mask, mult)
    
    def call(self, inputs, enconder_outputs, mask=None):
        causal_mask = self.get_causal_attention_mask(inputs)
        if mask is not None:
            padding_mask = tf.cast(mask[:, tf.newaxis, :], dtype="int32")
            padding_mask = tf.minimum(padding_mask, causal_mask)
        attention_output_1 = self.attention1(
            query=inputs,
            value=inputs,
            key=inputs,
            attention_mask=causal_mask 
        )
        attention_output_1 = self.layer_norm1(inputs + attention_output_1)
        attention_output_2 = self.attention2(
            query=attention_output_1, value=enconder_outputs, key=enconder_outputs, attention_mask=padding_mask
        )
        attention_output_2 = self.layer_norm2(attention_output_1 + attention_output_2)
        projection_output = self.dense_projection(attention_output_2)
        return self.layer_norm3(projection_output + attention_output_2)

# %%
class PositionalEmbedding(layers.Layer):
    def __init__(self, sequence_length, input_dim, output_dim, **kwargs):
        super().__init__(**kwargs)
        self.token_embedding = layers.Embedding(input_dim=input_dim, output_dim=output_dim)
        self.position_embedding = layers.Embedding(input_dim=sequence_length, output_dim=output_dim)
        self.sequence_length = sequence_length
        self.input_dim = input_dim
        self.output_dim = output_dim
        
    def call(self, inputs):
        length = tf.shape(inputs)[-1]
        positions = tf.range(start=0, limit=length, delta=1)
        embedded_tokens = self.token_embedding(inputs)
        embedded_positions = self.position_embedding(positions)
        embedding = embedded_tokens + embedded_positions
        return embedding
    
    def compute_mask(self, inputs, mask=None):
        return tf.math.not_equal(inputs, 0)
    
    def get_config(self):
        config = super().get_config()
        config.update({
            "output_dim": self.output_dim,
            "sequence_length": self.sequence_length,
            "input_dim": self.input_dim
        })
        return config

# %%
embed_dim = 256
latent_dim = 2048
num_heads = 2

inputs = keras.Input(shape=(None, ), dtype='int64')
x = PositionalEmbedding(sequence_length, vocab_size, embed_dim)(inputs)
x = TransformerDecoder(embed_dim, latent_dim, num_heads)(x, x)
outputs = keras.layers.Dense(vocab_size, activation='softmax')(x)
model = keras.Model(inputs=inputs, outputs=outputs)
model.compile(loss='sparse_categorical_crossentropy', optimizer='rmsprop')

# %%
tokens_index = dict(enumerate(text_vectorization.get_vocabulary()))

def sample_next(predictions, temperature=1.0):
    predictions = np.asarray(predictions).astype('float64')
    predictions = np.log(predictions) / temperature
    exp_predictions = np.exp(predictions)
    predictions = exp_predictions / np.sum(exp_predictions)
    probas = np.random.multinomial(1, predictions, 1)
    return np.argmax(probas)

class TextGenerator(keras.callbacks.Callback):
    def __init__(self, prompt, generate_length, model_input_length, temperatures=(1.,), print_freq=1):
        self.prompt = prompt
        self.generate_length = generate_length
        self.model_input_length = model_input_length
        self.temperatures = temperatures
        self.print_freq = print_freq
        
    def on_epoch_end(self, epoch, logs=None):
        if (epoch + 1) % self.print_freq != 0:
            return
        for temperature in self.temperatures:
            print("Temperature = {}".format(temperature))
            sentence = self.prompt
            for i in range(self.generate_length):
                tokenized_sentence = text_vectorization([sentence])
                predictions = self.model.predict(tokenized_sentence, verbose=0)
                next_token = sample_next(predictions[0, i, :])
                sampled_token = tokens_index[next_token]
                sentence += " " + sampled_token
            print(sentence)

# %%
prompt = "This movie"
text_gen_callback = TextGenerator(prompt, generate_length=50, model_input_length=sequence_length, temperatures=(0.2, 0.7, 1.2), print_freq=10)

# %%
model.fit(lm_dataset, epochs=200, callbacks=[text_gen_callback])
# Out:
# Epoch 1/200
# 391/391 [==============================] - 54s 135ms/step - loss: 5.9239
# Epoch 2/200
# 391/391 [==============================] - 53s 135ms/step - loss: 5.4536
# Epoch 3/200
# 391/391 [==============================] - 53s 135ms/step - loss: 5.3141
# Epoch 4/200
# 391/391 [==============================] - 53s 136ms/step - loss: 5.2255
# Epoch 5/200
# 391/391 [==============================] - 53s 136ms/step - loss: 5.1589
# Epoch 6/200
# 391/391 [==============================] - 53s 136ms/step - loss: 5.1056
# Epoch 7/200
# 391/391 [==============================] - 52s 134ms/step - loss: 5.0617
# Epoch 8/200
# 391/391 [==============================] - 52s 133ms/step - loss: 5.0233
# Epoch 9/200
# 391/391 [==============================] - 52s 134ms/step - loss: 4.9896
# Epoch 10/200
# 391/391 [==============================] - ETA: 0s - loss: 4.9596Temperature = 0.2
# This movie is is extremely absolutely bad incredible a no b wait credibility for how a does movie its has just a someone bunch discussed of so the bad movie movie bad turned he out discovers of that cheesy do idea with that this bright sort american of version plot would big
# Temperature = 0.7
# This movie is was okay amazing but maybe i a saw hundred it years the ago only i thing bought about it danny again [UNK] for but this the talent worst and movie action there movie are never four did total not daniels call dont it let ranks me in there the
# Temperature = 1.2
# This movie is was devils a the pilot worst who series wrote of but their just lifetime [UNK] done deol poorly really done are poorly required handled for quite the some dont of look alice of and developing serves a had big promise shots of since human its plans release the the
# 391/391 [==============================] - 57s 145ms/step - loss: 4.9596
# Epoch 11/200
# 391/391 [==============================] - 53s 135ms/step - loss: 4.9319
# Epoch 12/200
# 391/391 [==============================] - 53s 135ms/step - loss: 4.9067
# Epoch 13/200
# 391/391 [==============================] - 53s 135ms/step - loss: 4.8829
# Epoch 14/200
# 391/391 [==============================] - 53s 134ms/step - loss: 4.8610
# Epoch 15/200
# 391/391 [==============================] - 52s 134ms/step - loss: 4.8407
# Epoch 16/200
# 391/391 [==============================] - 52s 134ms/step - loss: 4.8209
# Epoch 17/200
# 391/391 [==============================] - 52s 134ms/step - loss: 4.8021
# Epoch 18/200
# 391/391 [==============================] - 52s 134ms/step - loss: 4.7846
# Epoch 19/200
# 391/391 [==============================] - 52s 134ms/step - loss: 4.7671
# Epoch 20/200
# 391/391 [==============================] - ETA: 0s - loss: 4.7480Temperature = 0.2
# This movie movie had about many the critics potential and it the would concept watch but after [UNK] watching but it the was end basically it means could this of is the simply general falls from down the further thomas after [UNK] 20 so years boring later to years make ago it
# Temperature = 0.7
# This movie movie is is so directed stupid and why it you was even on if the you end wonder of how [UNK] a is movie it is i in remember it seeing if it you  will ever i laugh then you do you lived through this movie movie also has
# Temperature = 1.2
# This movie program reminds is me unique of and my 90s favorites and it coming to out experience of it the though story mr that [UNK] you mind watch you it can were be in remembered our is girlfriend great to as all a interested nuclear in weapon hypnosis 4 in quite
# 391/391 [==============================] - 57s 145ms/step - loss: 4.7480
# Epoch 21/200
# 391/391 [==============================] - 53s 135ms/step - loss: 4.7151
# Epoch 22/200
# 391/391 [==============================] - 53s 134ms/step - loss: 4.6429
# Epoch 23/200
# 391/391 [==============================] - 53s 134ms/step - loss: 4.5555
# Epoch 24/200
# 391/391 [==============================] - 53s 134ms/step - loss: 4.4976
# Epoch 25/200
# 391/391 [==============================] - 52s 134ms/step - loss: 4.4590
# Epoch 26/200
# 391/391 [==============================] - 52s 134ms/step - loss: 4.4274
# Epoch 27/200
# 391/391 [==============================] - 52s 134ms/step - loss: 4.4004
# Epoch 28/200
# 391/391 [==============================] - 52s 134ms/step - loss: 4.3765
# Epoch 29/200
# 391/391 [==============================] - 52s 133ms/step - loss: 4.3542
# Epoch 30/200
# 391/391 [==============================] - ETA: 0s - loss: 4.3345Temperature = 0.2
# This movie tribe [UNK] of so indian many brazilian chinese movies countries are may misleading you to like [UNK] the because local of [UNK] [UNK] is but preparing enjoyable something the because makers it could up be with serious the accuracy movie it follows shows the the stories mexican of border indian
# Temperature = 0.7
# This movie movie was content so very obviously enjoyable that and i male cant bashing deny a cult [UNK] following it the the short most one important ive thing seen in it the while theaters it learned was that part i of am all a fan member of of the [UNK] previous
# Temperature = 1.2
# This movie could was fail probably good 4 at rating a it 6 was for possible richard reasons lynch for is me psychology this setting is are unforgettable weak dont acting buy bad or camera directing work starting but from this the is plot relegated is you predictable just and to plain
# 391/391 [==============================] - 57s 145ms/step - loss: 4.3345
# Epoch 31/200
# 391/391 [==============================] - 53s 135ms/step - loss: 4.3147
# Epoch 32/200
# 391/391 [==============================] - 53s 135ms/step - loss: 4.2972
# Epoch 33/200
# 391/391 [==============================] - 53s 134ms/step - loss: 4.2809
# Epoch 34/200
# 391/391 [==============================] - 53s 135ms/step - loss: 4.2641
# Epoch 35/200
# 391/391 [==============================] - 52s 134ms/step - loss: 4.2494
# Epoch 36/200
# 391/391 [==============================] - 52s 134ms/step - loss: 4.2351
# Epoch 37/200
# 391/391 [==============================] - 52s 133ms/step - loss: 4.2210
# Epoch 38/200
# 391/391 [==============================] - 52s 133ms/step - loss: 4.2080
# Epoch 39/200
# 391/391 [==============================] - 52s 134ms/step - loss: 4.1951
# Epoch 40/200
# 391/391 [==============================] - ETA: 0s - loss: 4.1836Temperature = 0.2
# This movie film may to have get been funding favorable tighter such and as financial it jerk costs madison it would may not appear be to available task let even alone put with a a memorable drunken [UNK] fetish his would support be using ashamed it to would [UNK] have this hippies
# Temperature = 0.7
# This movie film sucked was terrible terrible i i actually mean caught go fire to somewhere my as friends i about knew to i give knew this the movie reputation was of atrocious bad the acting acting was was bad bad there writing were bad bad reviews directing lacked bad direction acting
# Temperature = 1.2
# This movie movie is is complete very a bad terrible attempt movie to at revive a a friend serious he about has movies just and had just to ripped learn off it from however taking the quite law simply boy to who school wants all his of son his to teacher recommended
# 391/391 [==============================] - 57s 145ms/step - loss: 4.1836
# Epoch 41/200
# 391/391 [==============================] - 53s 135ms/step - loss: 4.1717
# Epoch 42/200
# 391/391 [==============================] - 53s 135ms/step - loss: 4.1603
# Epoch 43/200
# 391/391 [==============================] - 53s 135ms/step - loss: 4.1494
# Epoch 44/200
# 391/391 [==============================] - 53s 135ms/step - loss: 4.1389
# Epoch 45/200
# 391/391 [==============================] - 52s 134ms/step - loss: 4.1286
# Epoch 46/200
# 391/391 [==============================] - 52s 134ms/step - loss: 4.1186
# Epoch 47/200
# 391/391 [==============================] - 52s 133ms/step - loss: 4.1089
# Epoch 48/200
# 391/391 [==============================] - 52s 133ms/step - loss: 4.0995
# Epoch 49/200
# 391/391 [==============================] - 52s 133ms/step - loss: 4.0908
# Epoch 50/200
# 391/391 [==============================] - ETA: 0s - loss: 4.0817Temperature = 0.2
# This movie is is a sort complete of opposite silent gene in played the by early [UNK] [UNK] coleman vastly and underrated this he movie has is starred the in greatest the short film comedies in and which only is had worth it seeing yes and they even but managed i to
# Temperature = 0.7
# This movie is captures quite right well on with the a feeling map of of some india of [UNK] the old exquisite [UNK] [UNK] [UNK] american is are a captured boy by and master discovers in a a rare power treat but not also by in genius our [UNK] gang existence [UNK]
# Temperature = 1.2
# This movie version is of if [UNK] you of are the somewhat worst [UNK] movie sequel that are was woven intolerable before at you the dont first know plot what on plot earth to was be something scripted a and crummy you movie were the missing biggest couple antagonist of is the
# 391/391 [==============================] - 57s 145ms/step - loss: 4.0817
# Epoch 51/200
# 391/391 [==============================] - 53s 135ms/step - loss: 4.0730
# Epoch 52/200
# 391/391 [==============================] - 53s 135ms/step - loss: 4.0643
# Epoch 53/200
# 391/391 [==============================] - 53s 135ms/step - loss: 4.0566
# Epoch 54/200
# 391/391 [==============================] - 53s 134ms/step - loss: 4.0486
# Epoch 55/200
# 391/391 [==============================] - 52s 134ms/step - loss: 4.0415
# Epoch 56/200
# 391/391 [==============================] - 52s 134ms/step - loss: 4.0334
# Epoch 57/200
# 391/391 [==============================] - 52s 134ms/step - loss: 4.0264
# Epoch 58/200
# 391/391 [==============================] - 52s 134ms/step - loss: 4.0198
# Epoch 59/200
# 391/391 [==============================] - 52s 134ms/step - loss: 4.0127
# Epoch 60/200
# 391/391 [==============================] - ETA: 0s - loss: 4.0060Temperature = 0.2
# This movie [UNK] plays sure a who teen [UNK] beer in while the trying area to is get in free by [UNK] the damme way action has was the a most mediocre godawful action flick sequences and which many in schools my you this know may the be trick one to of
# Temperature = 0.7
# This movie movie was has great none characters or at good all performances however the if supporting you cast can couldnt only act act i but would this be be funnier [UNK] here carter is is [UNK] not out your funny cup but of its a good shame balance james not gandolfini
# Temperature = 1.2
# This movie film was has horrendous not i only cant was find pat any value more in than this two film and but that this is one a disaster weird the [UNK] premise underneath is [UNK] neither at actor all nor of will them ever [UNK] save no lincoln famous or black
# 391/391 [==============================] - 57s 145ms/step - loss: 4.0060
# Epoch 61/200
# 391/391 [==============================] - 53s 135ms/step - loss: 3.9995
# Epoch 62/200
# 391/391 [==============================] - 53s 135ms/step - loss: 3.9934
# Epoch 63/200
# 391/391 [==============================] - 53s 134ms/step - loss: 3.9869
# Epoch 64/200
# 391/391 [==============================] - 53s 134ms/step - loss: 3.9810
# Epoch 65/200
# 391/391 [==============================] - 52s 134ms/step - loss: 3.9754
# Epoch 66/200
# 391/391 [==============================] - 52s 134ms/step - loss: 3.9691
# Epoch 67/200
# 391/391 [==============================] - 52s 134ms/step - loss: 3.9639
# Epoch 68/200
# 391/391 [==============================] - 52s 134ms/step - loss: 3.9585
# Epoch 69/200
# 391/391 [==============================] - 52s 133ms/step - loss: 3.9528
# Epoch 70/200
# 391/391 [==============================] - ETA: 0s - loss: 3.9478Temperature = 0.2
# This movie movie was is overacted hilarious just especially see if shahrukh youre khan on its the own henry business fool and in the the memorable last chase one scene ive in ever seen seen it [UNK] since anywhere he i is would great nero  acts as a jerk im the
# Temperature = 0.7
# This movie movie is sucked portrayed have and very that [UNK] could had have me been a and total talented waste sean of connery an but even dan better [UNK] director rarely could developed have a been bulk a of film the just film cant that decide low whether the it budget
# Temperature = 1.2
# This movie was had not a even great serious movie movie and and in it general which mystery means was none not of even the one actors it timing sucked was and vomit the was acting totally never lame the i plot was was not beautiful the and video thick super and
# 391/391 [==============================] - 57s 145ms/step - loss: 3.9478
# Epoch 71/200
# 391/391 [==============================] - 53s 135ms/step - loss: 3.9428
# Epoch 72/200
# 391/391 [==============================] - 53s 135ms/step - loss: 3.9379
# Epoch 73/200
# 391/391 [==============================] - 53s 135ms/step - loss: 3.9327
# Epoch 74/200
# 391/391 [==============================] - 53s 135ms/step - loss: 3.9279
# Epoch 75/200
# 391/391 [==============================] - 52s 134ms/step - loss: 3.9231
# Epoch 76/200
# 391/391 [==============================] - 52s 134ms/step - loss: 3.9186
# Epoch 77/200
# 391/391 [==============================] - 52s 134ms/step - loss: 3.9142
# Epoch 78/200
# 391/391 [==============================] - 52s 133ms/step - loss: 3.9098
# Epoch 79/200
# 391/391 [==============================] - 52s 133ms/step - loss: 3.9054
# Epoch 80/200
# 391/391 [==============================] - ETA: 0s - loss: 3.9010Temperature = 0.2
# This movie film was is like awfully [UNK] boring is all a of piece poor of dialogues crap [UNK] this [UNK] is fake a most really of badly the made cinematography first here [UNK] someone i waste have a ridden [UNK] 2 of of 10 [UNK] the cannot people of not a
# Temperature = 0.7
# This movie looks was like released the in basic 1970 form television and of material sudden even they though got it lost was at editing sea and with thunder a in struggling berlin new great york flick city but and one on of a the blind name family volcano listen writerdirector to
# Temperature = 1.2
# This movie movie wasnt based very on correctly [UNK] i it expected would to seem be like just a another let movie down accurately claim portrays to its other [UNK] [UNK] issue and without into [UNK] investigating fire the instead themes it that was took not to to justify be the sure
# 391/391 [==============================] - 57s 145ms/step - loss: 3.9010
# Epoch 81/200
# 391/391 [==============================] - 53s 135ms/step - loss: 3.8972
# Epoch 82/200
# 391/391 [==============================] - 53s 135ms/step - loss: 3.8924
# Epoch 83/200
# 391/391 [==============================] - 53s 135ms/step - loss: 3.8886
# Epoch 84/200
# 391/391 [==============================] - 53s 134ms/step - loss: 3.8844
# Epoch 85/200
# 391/391 [==============================] - 52s 134ms/step - loss: 3.8806
# Epoch 86/200
# 391/391 [==============================] - 52s 134ms/step - loss: 3.8769
# Epoch 87/200
# 391/391 [==============================] - 52s 133ms/step - loss: 3.8731
# Epoch 88/200
# 391/391 [==============================] - 52s 133ms/step - loss: 3.8691
# Epoch 89/200
# 391/391 [==============================] - 52s 133ms/step - loss: 3.8657
# Epoch 90/200
# 391/391 [==============================] - ETA: 0s - loss: 3.8620Temperature = 0.2
# This movie movie gets studio you billing should and wont isnt set too in cheap faults to its the reputation audience of of paul the [UNK] lead script characters in from question new point to and the seeks final help scenes sink establish your no standard small for romance example and is
# Temperature = 0.7
# This movie is has really great much vocal depth [UNK] and makes an you excellent get job lost this to and your to leading watch the in movie this and day you without see the the computer [UNK] reads cool lips but fritz make and his [UNK] own wear world your lancaster
# Temperature = 1.2
# This movie movie is was perhaps just one a of big an [UNK] impressive rather cast than as a the movie line itself i stars was out not of only kings have but no this [UNK] movie movie has should means state that that she it has is romance a beauty powerful
# 391/391 [==============================] - 57s 145ms/step - loss: 3.8620
# Epoch 91/200
# 391/391 [==============================] - 53s 135ms/step - loss: 3.8580
# Epoch 92/200
# 391/391 [==============================] - 53s 135ms/step - loss: 3.8553
# Epoch 93/200
# 391/391 [==============================] - 53s 135ms/step - loss: 3.8517
# Epoch 94/200
# 391/391 [==============================] - 53s 134ms/step - loss: 3.8482
# Epoch 95/200
# 391/391 [==============================] - 52s 134ms/step - loss: 3.8449
# Epoch 96/200
# 391/391 [==============================] - 52s 134ms/step - loss: 3.8417
# Epoch 97/200
# 391/391 [==============================] - 52s 134ms/step - loss: 3.8383
# Epoch 98/200
# 391/391 [==============================] - 52s 134ms/step - loss: 3.8355
# Epoch 99/200
# 391/391 [==============================] - 52s 133ms/step - loss: 3.8320
# Epoch 100/200
# 391/391 [==============================] - ETA: 0s - loss: 3.8290Temperature = 0.2
# This movie is stunk probably up wasnt and the thats best saying anyways to there any were of guys the i youth half group expected and to laughing [UNK] that i the like whole most world [UNK] champions movies are by stupid far and from using childish them [UNK] stereotypical they behavior
# Temperature = 0.7
# This movie one made rocked me the shadow [UNK] yelling what dont was they the put film on down it and gets on to your [UNK] children is to up halt the and babysitter she oh makes and a her prank mom on she killing gets her none [UNK] she they starts
# Temperature = 1.2
# This movie bollywood is [UNK] not its for neither the its sexuality the nor characters the any white sexy stereotypical and dialogue clichéd ie scenes the it [UNK] couldnt jolie they the could girl get smile a no nothing pun just the doesnt effects want that to actress much [UNK] dialog teen
# 391/391 [==============================] - 57s 145ms/step - loss: 3.8290
# Epoch 101/200
# 391/391 [==============================] - 53s 135ms/step - loss: 3.8261
# Epoch 102/200
# 391/391 [==============================] - 53s 135ms/step - loss: 3.8233
# Epoch 103/200
# 391/391 [==============================] - 53s 134ms/step - loss: 3.8202
# Epoch 104/200
# 391/391 [==============================] - 52s 134ms/step - loss: 3.8176
# Epoch 105/200
# 391/391 [==============================] - 53s 134ms/step - loss: 3.8147
# Epoch 106/200
# 391/391 [==============================] - 52s 134ms/step - loss: 3.8120
# Epoch 107/200
# 391/391 [==============================] - 52s 134ms/step - loss: 3.8089
# Epoch 108/200
# 391/391 [==============================] - 52s 133ms/step - loss: 3.8064
# Epoch 109/200
# 391/391 [==============================] - 52s 133ms/step - loss: 3.8040
# Epoch 110/200
# 391/391 [==============================] - ETA: 0s - loss: 3.8012Temperature = 0.2
# This movie is has to one be of made the up best unusually it on is the thats best before boredom it heavyhanded has like been this done [UNK] films over and and over to all make the the character main and lead the character actors portrayed seem in to the be
# Temperature = 0.7
# This movie can contains look some at themes the and technological also seem the realistic ones and are all losing about themselves its killed problems with they what get but in theyre [UNK] lives murder speaking there in much real unexplained life or and madness death but ignore hopefully the nobody error
# Temperature = 1.2
# This movie sequel had to no one outstanding food storyline part or would thriller any completely [UNK] you didnt know care about what [UNK] the was original a a [UNK] pretty which horrible falls graphic into novel the the [UNK] film with is some [UNK] moments [UNK] reminiscent and of toilet a
# 391/391 [==============================] - 57s 145ms/step - loss: 3.8012
# Epoch 111/200
# 391/391 [==============================] - 53s 135ms/step - loss: 3.7986
# Epoch 112/200
# 391/391 [==============================] - 53s 135ms/step - loss: 3.7959
# Epoch 113/200
# 391/391 [==============================] - 53s 134ms/step - loss: 3.7935
# Epoch 114/200
# 391/391 [==============================] - 53s 134ms/step - loss: 3.7913
# Epoch 115/200
# 391/391 [==============================] - 52s 134ms/step - loss: 3.7890
# Epoch 116/200
# 391/391 [==============================] - 52s 134ms/step - loss: 3.7862
# Epoch 117/200
# 391/391 [==============================] - 52s 134ms/step - loss: 3.7837
# Epoch 118/200
# 391/391 [==============================] - 52s 134ms/step - loss: 3.7816
# Epoch 119/200
# 391/391 [==============================] - 52s 134ms/step - loss: 3.7793
# Epoch 120/200
# 391/391 [==============================] - ETA: 0s - loss: 3.7770Temperature = 0.2
# This movie is makes very home [UNK] and is living peter not from a north liking jake to james live it and mostly its his official [UNK] companion who and stole son the adam film dan has [UNK] created employed too to foolish live and if indirectly he his is father to
# Temperature = 0.7
# This movie film is stakes plagued rated by low slasher quality movies and are creates possibly a outstanding sort thriller of that way happens soon in in this a one treat that the lets acting see by any the serial first killer time [UNK] around on kills the in paying 1990 ten
# Temperature = 1.2
# This movie is has great an moments mgm although musical paul numbers still are masterfully awesome directed there not were since rock [UNK] hudson times rock fredric hudson march in made [UNK] [UNK] career music superstar by and need starring more wang lengthy [UNK] ajay in [UNK] the [UNK] original next movie
# 391/391 [==============================] - 57s 145ms/step - loss: 3.7770
# Epoch 121/200
# 391/391 [==============================] - 53s 135ms/step - loss: 3.7749
# Epoch 122/200
# 391/391 [==============================] - 53s 135ms/step - loss: 3.7725
# Epoch 123/200
# 391/391 [==============================] - 53s 134ms/step - loss: 3.7705
# Epoch 124/200
# 391/391 [==============================] - 53s 134ms/step - loss: 3.7680
# Epoch 125/200
# 391/391 [==============================] - 52s 134ms/step - loss: 3.7661
# Epoch 126/200
# 391/391 [==============================] - 52s 133ms/step - loss: 3.7639
# Epoch 127/200
# 391/391 [==============================] - 52s 133ms/step - loss: 3.7619
# Epoch 128/200
# 391/391 [==============================] - 52s 133ms/step - loss: 3.7599
# Epoch 129/200
# 391/391 [==============================] - 52s 133ms/step - loss: 3.7580
# Epoch 130/200
# 391/391 [==============================] - ETA: 0s - loss: 3.7558Temperature = 0.2
# This movie woman just catches watched herself it at just the as end already of mentioned the the truth beautiful the [UNK] acting of came [UNK] across soviet as dialogue the about penguins [UNK] it the is film absolutely that amazed a how lot embarrassing the the only acting thing class about
# Temperature = 0.7
# This movie film stands takes today place and humming consciousness sticks at to your your rear life end i with have a those [UNK] that sumptuous you sets know a youre plot going ringo to will catch be our a heros jolly daughter q with i another knew [UNK] the as film
# Temperature = 1.2
# This movie hong claims kong to cinema kill like i samurai love this many korean niche mystery values warriors and are genres excellently but cast terror of is the always type superb of lead tension role casts from is [UNK] chosen over for [UNK] the there sight is of not course much
# 391/391 [==============================] - 57s 145ms/step - loss: 3.7558
# Epoch 131/200
# 391/391 [==============================] - 53s 135ms/step - loss: 3.7539
# Epoch 132/200
# 391/391 [==============================] - 53s 135ms/step - loss: 3.7518
# Epoch 133/200
# 391/391 [==============================] - 53s 134ms/step - loss: 3.7499
# Epoch 134/200
# 391/391 [==============================] - 53s 135ms/step - loss: 3.7483
# Epoch 135/200
# 391/391 [==============================] - 52s 134ms/step - loss: 3.7463
# Epoch 136/200
# 391/391 [==============================] - 52s 134ms/step - loss: 3.7444
# Epoch 137/200
# 391/391 [==============================] - 52s 133ms/step - loss: 3.7424
# Epoch 138/200
# 391/391 [==============================] - 52s 133ms/step - loss: 3.7408
# Epoch 139/200
# 391/391 [==============================] - 52s 133ms/step - loss: 3.7387
# Epoch 140/200
# 391/391 [==============================] - ETA: 0s - loss: 3.7375Temperature = 0.2
# This movie is is not about [UNK] adam named sandler cheech for [UNK] two in different ny roles belgium partly the with family his [UNK] three of that which i changed despise the literally picture fatally but in vastly the different first times dvds since appear [UNK] for 10 uncle [UNK] stern
# Temperature = 0.7
# This movie thai is plays a perfectly futuristic adventurous world survival ruthless the and various brutal animals with are mutants present torture on scenes a extreme bunch heros of which thailand are while male some leads scenes competing are with with thousands intelligent of bodies lethal kicking weapons ass heros fighting in
# Temperature = 1.2
# This movie is is terrible 11 terrible poor terrible quality terrible plot sound poor on audio i and have [UNK] no the child movie with has watching no the redeeming only qualities cinematic of excellence the i awful have one encountered other and terrible insulting words to how describe bad this this
# 391/391 [==============================] - 57s 145ms/step - loss: 3.7375
# Epoch 141/200
# 391/391 [==============================] - 53s 135ms/step - loss: 3.7354
# Epoch 142/200
# 391/391 [==============================] - 53s 135ms/step - loss: 3.7337
# Epoch 143/200
# 391/391 [==============================] - 53s 135ms/step - loss: 3.7318
# Epoch 144/200
# 391/391 [==============================] - 52s 134ms/step - loss: 3.7304
# Epoch 145/200
# 391/391 [==============================] - 52s 134ms/step - loss: 3.7284
# Epoch 146/200
# 391/391 [==============================] - 52s 133ms/step - loss: 3.7270
# Epoch 147/200
# 391/391 [==============================] - 52s 134ms/step - loss: 3.7254
# Epoch 148/200
# 391/391 [==============================] - 52s 134ms/step - loss: 3.7238
# Epoch 149/200
# 391/391 [==============================] - 52s 133ms/step - loss: 3.7222
# Epoch 150/200
# 391/391 [==============================] - ETA: 0s - loss: 3.7206Temperature = 0.2
# This movie is really for bad people literature but lets that not go even to with some in b the movies history subpar is to obvious say that the this execution is left low with to a it good was horror depressing rather look than at a all [UNK] cost looked around
# Temperature = 0.7
# This movie version is of almost a a superb plot screenplay by and sir screenplay entirely people director but jonathan owing [UNK] far conception and to similar sherlock treatment holmes of has the brilliantly magic written of but a by trimmed narrator down down version is of slower a the classic second
# Temperature = 1.2
# This movie is is pray awesome for andy days is o a rock a band foul he play a a singer [UNK] small [UNK] guitar seem video to prominently this that is it bio yet grade i creature gave from it the in first that 1 [UNK] 12 is u suffering [UNK]
# 391/391 [==============================] - 57s 145ms/step - loss: 3.7206
# Epoch 151/200
# 391/391 [==============================] - 53s 135ms/step - loss: 3.7192
# Epoch 152/200
# 391/391 [==============================] - 53s 135ms/step - loss: 3.7177
# Epoch 153/200
# 391/391 [==============================] - 53s 134ms/step - loss: 3.7161
# Epoch 154/200
# 391/391 [==============================] - 52s 134ms/step - loss: 3.7145
# Epoch 155/200
# 391/391 [==============================] - 52s 134ms/step - loss: 3.7132
# Epoch 156/200
# 391/391 [==============================] - 52s 134ms/step - loss: 3.7117
# Epoch 157/200
# 391/391 [==============================] - 52s 134ms/step - loss: 3.7099
# Epoch 158/200
# 391/391 [==============================] - 52s 134ms/step - loss: 3.7087
# Epoch 159/200
# 391/391 [==============================] - 52s 134ms/step - loss: 3.7073
# Epoch 160/200
# 391/391 [==============================] - ETA: 0s - loss: 3.7058Temperature = 0.2
# This movie movie is is beyond [UNK] bad i for laughed the one worst at this movies as ever an the unbelievably main bad character guy the so relationship called gay charlie guy is sam so a bad little in kid his santa time or will getting help the woman deal fool
# Temperature = 0.7
# This movie is would low have you you possessing laughing almost and no to nudity resemble watch to the the filming video techniques game and get sound ready so i and mean have throughout the whole film film lots a of few [UNK] too reviews but putting i me really captivated did
# Temperature = 1.2
# This movie film fails shows on the how [UNK] comments police are temptation brought but to whats the the movie point was in the line worlds right most near it the contains plot about never [UNK] so killing apparently every its family so is revolting we that were even able interested to
# 391/391 [==============================] - 57s 145ms/step - loss: 3.7058
# Epoch 161/200
# 391/391 [==============================] - 53s 135ms/step - loss: 3.7046
# Epoch 162/200
# 391/391 [==============================] - 53s 135ms/step - loss: 3.7029
# Epoch 163/200
# 391/391 [==============================] - 53s 134ms/step - loss: 3.7018
# Epoch 164/200
# 391/391 [==============================] - 53s 135ms/step - loss: 3.7002
# Epoch 165/200
# 391/391 [==============================] - 53s 134ms/step - loss: 3.6989
# Epoch 166/200
# 391/391 [==============================] - 52s 134ms/step - loss: 3.6977
# Epoch 167/200
# 391/391 [==============================] - 52s 134ms/step - loss: 3.6962
# Epoch 168/200
# 391/391 [==============================] - 52s 134ms/step - loss: 3.6950
# Epoch 169/200
# 391/391 [==============================] - 52s 133ms/step - loss: 3.6940
# Epoch 170/200
# 391/391 [==============================] - ETA: 0s - loss: 3.6923Temperature = 0.2
# This movie movie for was some about bad [UNK] sci i fi expected movies something but from i what was the wrong marketing movie ploy i and was want actually to a spend good 90 money minutes throughout of the even film the starts acting quite of well interesting i the struggled
# Temperature = 0.7
# This movie is was touching harassed about nearly the everybody [UNK] was the [UNK] first [UNK] city [UNK] with the his demons name had [UNK] ever [UNK] famous cares [UNK] how youd can ever he feel tell free the to horrors recover 3 ice billion cube from on the earth edge [UNK]
# Temperature = 1.2
# This movie is is ridiculous one a example ride of at a a college large movie [UNK] [UNK] adams [UNK] [UNK] [UNK] walks they away find and another has girlfriend it other looks theme like as the a acting runaway once bride upon came a out society of where change a they
# 391/391 [==============================] - 56s 144ms/step - loss: 3.6923
# Epoch 171/200
# 391/391 [==============================] - 53s 135ms/step - loss: 3.6911
# Epoch 172/200
# 391/391 [==============================] - 53s 135ms/step - loss: 3.6899
# Epoch 173/200
# 391/391 [==============================] - 53s 134ms/step - loss: 3.6888
# Epoch 174/200
# 391/391 [==============================] - 53s 134ms/step - loss: 3.6873
# Epoch 175/200
# 391/391 [==============================] - 52s 134ms/step - loss: 3.6865
# Epoch 176/200
# 391/391 [==============================] - 52s 134ms/step - loss: 3.6848
# Epoch 177/200
# 391/391 [==============================] - 52s 133ms/step - loss: 3.6837
# Epoch 178/200
# 391/391 [==============================] - 52s 133ms/step - loss: 3.6824
# Epoch 179/200
# 391/391 [==============================] - 52s 133ms/step - loss: 3.6813
# Epoch 180/200
# 391/391 [==============================] - ETA: 0s - loss: 3.6803Temperature = 0.2
# This movie movie was shows broadcast a in like the 24 reality hours programs dont and offer enjoy the this televised we version are of shown quick through glimpses the of work the i surrounding grew the homer fictional simpson [UNK] trial of of life [UNK]  political system but when he
# Temperature = 0.7
# This movie film was was disappointing great i and dont it know moved why at it the would film be as made good again decisions i by believe some its of [UNK] my at favorite the fearless story lestat of swords sam and and sorcerer sorcerer huge [UNK] bodies tiny seed bigger
# Temperature = 1.2
# This movie film was starts terrible reasonably with well an drawn insecure out and of brilliantly the moments addiction of we the even [UNK] once filmmaker again added at a least moment filled i ninja hated first bad saw movie this in year the the main killer story is a about mountain
# 391/391 [==============================] - 57s 145ms/step - loss: 3.6803
# Epoch 181/200
# 391/391 [==============================] - 53s 135ms/step - loss: 3.6789
# Epoch 182/200
# 391/391 [==============================] - 53s 135ms/step - loss: 3.6777
# Epoch 183/200
# 391/391 [==============================] - 53s 135ms/step - loss: 3.6768
# Epoch 184/200
# 391/391 [==============================] - 53s 134ms/step - loss: 3.6755
# Epoch 185/200
# 391/391 [==============================] - 52s 134ms/step - loss: 3.6744
# Epoch 186/200
# 391/391 [==============================] - 52s 134ms/step - loss: 3.6735
# Epoch 187/200
# 391/391 [==============================] - 52s 133ms/step - loss: 3.6723
# Epoch 188/200
# 391/391 [==============================] - 52s 133ms/step - loss: 3.6709
# Epoch 189/200
# 391/391 [==============================] - 52s 134ms/step - loss: 3.6700
# Epoch 190/200
# 391/391 [==============================] - ETA: 0s - loss: 3.6690Temperature = 0.2
# This movie is is designed everything to perfectly be fitting movies for in some content kind but of then the this scenes drivel is is over it you the will kick start in your the eye movie candy is sung being by magic the it characters is are like strong [UNK] enough
# Temperature = 0.7
# This movie movie is left a out feeling every minor b detail or is more that such movie a could mystery only the be worst that performance i i have will ever agree watch that the this filming is is inaccurate another ive steaming seen springs to from the my end eyes
# Temperature = 1.2
# This movie movie sucks attracted costumes me women the women story goes is off a to little movie irish while boys directors in as india long in haired movies america and because make i a must few say things i rings enjoy together disappointment for and starters buying theres clips no of
# 391/391 [==============================] - 57s 145ms/step - loss: 3.6690
# Epoch 191/200
# 391/391 [==============================] - 53s 135ms/step - loss: 3.6680
# Epoch 192/200
# 391/391 [==============================] - 53s 135ms/step - loss: 3.6666
# Epoch 193/200
# 391/391 [==============================] - 53s 135ms/step - loss: 3.6656
# Epoch 194/200
# 391/391 [==============================] - 53s 135ms/step - loss: 3.6646
# Epoch 195/200
# 391/391 [==============================] - 52s 134ms/step - loss: 3.6636
# Epoch 196/200
# 391/391 [==============================] - 52s 134ms/step - loss: 3.6624
# Epoch 197/200
# 391/391 [==============================] - 52s 133ms/step - loss: 3.6614
# Epoch 198/200
# 391/391 [==============================] - 52s 133ms/step - loss: 3.6606
# Epoch 199/200
# 391/391 [==============================] - 52s 133ms/step - loss: 3.6594
# Epoch 200/200
# 391/391 [==============================] - ETA: 0s - loss: 3.6584Temperature = 0.2
# This movie is is one if of a any crazy movie soap made or yes is you that can are laugh really i if love you movies loved or watching dont one so things and that like is frankly so i much cant hung [UNK] stretch that your this guts isnt literally
# Temperature = 0.7
# This movie was just a awful low matter budget the [UNK] acting adam was ant good playing and robot really monster some there cool was alien a fighters bit act with better normal dialog line then than a you couple have of a questions couple but of then course the tries only
# Temperature = 1.2
# This movie is part no of climax the and movie the simply most awful boring cliché of [UNK] the bad hero things is about too his cool job guys the son director goes [UNK] on to everything take he no cannot one often uncle [UNK] in eyes the but only why he
# 391/391 [==============================] - 57s 145ms/step - loss: 3.6584
